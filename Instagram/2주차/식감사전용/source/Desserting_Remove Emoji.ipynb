# %%
import pandas as pd
import re 
import math

# csv 파일 읽어오기
raw_data = pd.read_csv('감성사전용 데이터_선익.csv', encoding='utf-8').drop('Unnamed: 0', axis=1)

raw_data.head()
# Out:
#         Nickname  ...                                            Hashtag
# 0     v_namukong  ...  #백순대#호남댁#백순대택배#신림맛집#...
# 1     v_namukong  ...  #뷰티인사이드#뷰티인사이드전시회#일상#셀카#셀피#셀스타그램#selfie#셀기꾼#소통...
# 2     mae_chelin  ...  #서울#동대문#답십리#답십리맛집#장원닭한마리#닭한마리#칼국수#전농동#전농동맛집#토리...
# 3  hae_dal_table  ...  #해달_첫끼#크럼블#찌니빵공장#앙구마크ᄅ...
# 4     mae_chelin  ...  #존맛탱#떡볶이밀키트#떡#어묵#소세지#튀...
#
# [5 rows x 3 columns]

# %%
# emoji를 지우는 함수

def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    
    return emoji_pattern.sub(r'', string)

# %%
# Review와 Hashtag에 적용

for i in range(len(raw_data)):
    raw_data['Review'][i] = remove_emoji(str(raw_data['Review'][i]))
    raw_data['Hashtag'][i] = remove_emoji(str(raw_data['Hashtag'][i]))

# %%
raw_data.head()
# Out:
#         Nickname  ...                                            Hashtag
# 0     v_namukong  ...  #백순대#호남댁#백순대택배#신림맛집#...
# 1     v_namukong  ...  #뷰티인사이드#뷰티인사이드전시회#일상#셀카#셀피#셀스타그램#selfie#셀기꾼#소통...
# 2     mae_chelin  ...  #서울#동대문#답십리#답십리맛집#장원닭한마리#닭한마리#칼국수#전농동#전농동맛집#토리...
# 3  hae_dal_table  ...  #해달_첫끼#크럼블#찌니빵공장#앙구마크ᄅ...
# 4     mae_chelin  ...  #존맛탱#떡볶이밀키트#떡#어묵#소세지#튀...
#
# [5 rows x 3 columns]

# %%
# Hashtag의 #을 지우는 코드

for i in range(len(raw_data)):
    if raw_data['Hashtag'][i] == "nan": # Hashtag가 아무것도 없을 경우
        raw_data['Hashtag'][i] = None   # None으로 변경
    else:
        raw_data['Hashtag'][i] = raw_data.Hashtag[i][1:].replace("#",",")

# %%
raw_data.head()
# Out:
#         Nickname  ...                                            Hashtag
# 0     v_namukong  ...  백순대,호남댁,백순대택배,신림맛집,ᄒ...
# 1     v_namukong  ...  뷰티인사이드,뷰티인사이드전시회,일상,셀카,셀피,셀스타그램,selfie,셀기꾼,소통해...
# 2     mae_chelin  ...  서울,동대문,답십리,답십리맛집,장원닭한마리,닭한마리,칼국수,전농동,전농동맛집,토리후...
# 3  hae_dal_table  ...  해달_첫끼,크럼블,찌니빵공장,앙구마크러...
# 4     mae_chelin  ...  존맛탱,떡볶이밀키트,떡,어묵,소세지,튀ᄀ...
#
# [5 rows x 3 columns]

# %%
raw_data.to_csv("Remove Emoji_선익.csv", encoding="utf-8")

# %%
raw_data = pd.read_csv('Remove Emoji_선익.csv', encoding='utf-8').drop('Unnamed: 0', axis=1)
